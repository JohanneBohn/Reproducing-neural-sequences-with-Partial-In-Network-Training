# %%
from rsc_data import plot_activation, get_snr

# %%
import pandas as pd
rsc_df = pd.read_csv('rscfull.csv')

# %%
print(rsc_df.shape)
# Out:
# (229, 144)

# %%
plot_activation(rsc_df, neuron_list=[0, 115, 116, 228])

# %%
get_snr(rsc_df, bg_frac=0.25)
# Out:
# {'mean_snr': 23.101061810491853,
#  'snr_per_neuron': array([24.27425734, 22.27197171, 23.19691852, 23.45637059, 22.50985241,
#         21.90040998, 23.2987627 , 22.41672513, 21.31854017, 24.49021773,
#         21.77713224, 23.22144582, 22.42439835, 22.33337543, 22.57964417,
#         21.84708092, 22.20166456, 24.44304772, 23.5666442 , 21.07909905,
#         23.199173  , 21.83282194, 23.3878102 , 22.55170282, 22.46703318,
#         25.8087271 , 23.31997028, 22.87121813, 23.00670592, 22.9671993 ,
#         23.4114677 , 23.07289047, 22.71632522, 22.84853327, 22.68447821,
#         24.33843499, 23.3567755 , 22.96139234, 23.78748621, 23.22381452,
#         24.05223209, 22.60709829, 22.1230044 , 22.82398996, 22.74728444,
#         22.93671878, 23.51675328, 21.36455178, 21.61527148, 27.41318607,
#         20.95519896, 21.70396925, 22.9618518 , 24.92451916, 21.54154381,
#         20.4425833 , 25.58941754, 23.58123671, 23.97729778, 25.07491013,
# ...
